# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import pickle
import optuna
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

# %%
df = pd.read_csv('reddit_preprocessing.csv').dropna(subset=['clean_comment'])
df.head()
# Out:
#                                        clean_comment  category
# 0  film absolutely awful, but nevertheless, hilar...         0
# 1  well since seeing part 1 3 honestly say never ...         0
# 2  got see film preview dazzled it. not typical r...         1
# 3  adaptation positively butcher classic beloved ...         0
# 4  rzone awful movie! simple. seems tried make mo...         0

# %%
X = df['clean_comment']
y = df['category']

# %%
# Train-Test Split + TF-IDF + SMOTE

ngram_range = (1, 3)  # Trigram
max_features = 10000

X_train, X_test, y_train, y_test = train_test_split(
    df['clean_comment'], df['category'],
    test_size=0.2, random_state=42, stratify=df['category']
)

vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Apply SMOTE
smote = SMOTE(random_state=42)
X_train_vec, y_train = smote.fit_resample(X_train_vec, y_train)

print("Training shape after SMOTE:", X_train_vec.shape)
# Out:
# Training shape after SMOTE: (19954, 10000)

# %%
# Optuna objective function for XGBoost

def objective_xgboost(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'random_state': 42,
        'eval_metric': 'logloss',
        'use_label_encoder': False
    }

    model = XGBClassifier(**params)
    model.fit(X_train_vec, y_train)
    preds = model.predict(X_test_vec)
    return accuracy_score(y_test, preds)

# %%
# Run Optuna for Hyperparameter Tuning
study = optuna.create_study(direction="maximize")
study.optimize(objective_xgboost, n_trials=20)  # Adjust n_trials if needed

print("Best Parameters:", study.best_params)
print("Best Accuracy:", study.best_value)

# Train final model with best params
best_model = XGBClassifier(**study.best_params, random_state=42, eval_metric='logloss', use_label_encoder=False)
best_model.fit(X_train_vec, y_train)
# Out:
# [I 2025-08-14 13:02:17,321] A new study created in memory with name: no-name-011256ab-9fa6-41bb-8a6a-35c5c5ce679c
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:02:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:04:25,061] Trial 0 finished with value: 0.6952419192933146 and parameters: {'n_estimators': 259, 'learning_rate': 0.0002861731505246053, 'max_depth': 4, 'subsample': 0.7359349934180666, 'colsample_bytree': 0.9757923054243242}. Best is trial 0 with value: 0.6952419192933146.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:04:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:10:14,070] Trial 1 finished with value: 0.8138927926119253 and parameters: {'n_estimators': 123, 'learning_rate': 0.02500078407130143, 'max_depth': 10, 'subsample': 0.8293163136590181, 'colsample_bytree': 0.8519817905493616}. Best is trial 1 with value: 0.8138927926119253.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:10:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:19:33,799] Trial 2 finished with value: 0.752258582613933 and parameters: {'n_estimators': 296, 'learning_rate': 0.0015299652966616847, 'max_depth': 8, 'subsample': 0.7482014448523929, 'colsample_bytree': 0.979875758709488}. Best is trial 1 with value: 0.8138927926119253.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:19:34] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:20:23,638] Trial 3 finished with value: 0.7191327042762498 and parameters: {'n_estimators': 150, 'learning_rate': 0.00943672467954979, 'max_depth': 3, 'subsample': 0.8242499406410468, 'colsample_bytree': 0.9899619964768565}. Best is trial 1 with value: 0.8138927926119253.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:20:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:28:08,964] Trial 4 finished with value: 0.8277454326440474 and parameters: {'n_estimators': 258, 'learning_rate': 0.019581930873269194, 'max_depth': 9, 'subsample': 0.7949056264521487, 'colsample_bytree': 0.7678899909173145}. Best is trial 4 with value: 0.8277454326440474.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:28:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:35:06,517] Trial 5 finished with value: 0.8359767115037141 and parameters: {'n_estimators': 179, 'learning_rate': 0.0364012176188422, 'max_depth': 10, 'subsample': 0.8863552667136625, 'colsample_bytree': 0.7916314518317974}. Best is trial 5 with value: 0.8359767115037141.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:35:07] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:42:34,665] Trial 6 finished with value: 0.7562738405942582 and parameters: {'n_estimators': 209, 'learning_rate': 0.0029163721888427964, 'max_depth': 8, 'subsample': 0.6933169518219948, 'colsample_bytree': 0.9954882288915343}. Best is trial 5 with value: 0.8359767115037141.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:42:35] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:45:58,563] Trial 7 finished with value: 0.7199357558723148 and parameters: {'n_estimators': 289, 'learning_rate': 0.0012665461681131303, 'max_depth': 5, 'subsample': 0.9997785167309279, 'colsample_bytree': 0.7806271901268985}. Best is trial 5 with value: 0.8359767115037141.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:45:59] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:49:36,731] Trial 8 finished with value: 0.7950210801043968 and parameters: {'n_estimators': 208, 'learning_rate': 0.014629457990624706, 'max_depth': 6, 'subsample': 0.83474548505171, 'colsample_bytree': 0.998514927680213}. Best is trial 5 with value: 0.8359767115037141.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:49:37] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:50:26,426] Trial 9 finished with value: 0.7225456735595261 and parameters: {'n_estimators': 67, 'learning_rate': 0.0007583624435434752, 'max_depth': 5, 'subsample': 0.7480013372434325, 'colsample_bytree': 0.8353219277397624}. Best is trial 5 with value: 0.8359767115037141.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:50:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:53:47,033] Trial 10 finished with value: 0.8339690825135515 and parameters: {'n_estimators': 98, 'learning_rate': 0.07176630979506093, 'max_depth': 10, 'subsample': 0.9430570330037377, 'colsample_bytree': 0.6560368597169676}. Best is trial 5 with value: 0.8359767115037141.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:53:47] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:56:30,539] Trial 11 finished with value: 0.8389881549889581 and parameters: {'n_estimators': 88, 'learning_rate': 0.09702080625543916, 'max_depth': 10, 'subsample': 0.9428880140400054, 'colsample_bytree': 0.6089506973419865}. Best is trial 11 with value: 0.8389881549889581.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:56:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 13:59:50,899] Trial 12 finished with value: 0.8472194338486247 and parameters: {'n_estimators': 169, 'learning_rate': 0.07713031172507841, 'max_depth': 8, 'subsample': 0.9122798896274109, 'colsample_bytree': 0.6389881668920729}. Best is trial 12 with value: 0.8472194338486247.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:59:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 14:01:03,527] Trial 13 finished with value: 0.811282874924714 and parameters: {'n_estimators': 52, 'learning_rate': 0.08490576029109928, 'max_depth': 8, 'subsample': 0.9216150772579248, 'colsample_bytree': 0.6054742395717202}. Best is trial 12 with value: 0.8472194338486247.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:01:04] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 14:03:10,770] Trial 14 finished with value: 0.764505119453925 and parameters: {'n_estimators': 108, 'learning_rate': 0.00593866298009489, 'max_depth': 7, 'subsample': 0.6031705187328009, 'colsample_bytree': 0.6945186787919617}. Best is trial 12 with value: 0.8472194338486247.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:03:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 14:06:41,830] Trial 15 finished with value: 0.8514354547279662 and parameters: {'n_estimators': 150, 'learning_rate': 0.09011526554823635, 'max_depth': 9, 'subsample': 0.9933283305239757, 'colsample_bytree': 0.6050847927667957}. Best is trial 15 with value: 0.8514354547279662.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:06:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 14:09:58,848] Trial 16 finished with value: 0.7420196747641036 and parameters: {'n_estimators': 152, 'learning_rate': 0.00010682403436895302, 'max_depth': 7, 'subsample': 0.9990149243019464, 'colsample_bytree': 0.7043356686154373}. Best is trial 15 with value: 0.8514354547279662.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:09:59] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 14:15:05,504] Trial 17 finished with value: 0.8426018871712507 and parameters: {'n_estimators': 193, 'learning_rate': 0.04530404370666388, 'max_depth': 9, 'subsample': 0.8874576626933923, 'colsample_bytree': 0.6704863835036928}. Best is trial 15 with value: 0.8514354547279662.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:15:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 14:20:30,245] Trial 18 finished with value: 0.7751455531017868 and parameters: {'n_estimators': 147, 'learning_rate': 0.007097099797803803, 'max_depth': 9, 'subsample': 0.9621876028497977, 'colsample_bytree': 0.6427121829552513}. Best is trial 15 with value: 0.8514354547279662.
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:20:36] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-08-14 14:23:38,197] Trial 19 finished with value: 0.835173659907649 and parameters: {'n_estimators': 221, 'learning_rate': 0.0409759034607435, 'max_depth': 6, 'subsample': 0.8964196100281399, 'colsample_bytree': 0.7465523188616209}. Best is trial 15 with value: 0.8514354547279662.
# Best Parameters: {'n_estimators': 150, 'learning_rate': 0.09011526554823635, 'max_depth': 9, 'subsample': 0.9933283305239757, 'colsample_bytree': 0.6050847927667957}
# Best Accuracy: 0.8514354547279662
# C:\jupyter\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:23:38] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6050847927667957, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, feature_weights=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.09011526554823635,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=150, n_jobs=None,
#               num_parallel_tree=None, ...)
